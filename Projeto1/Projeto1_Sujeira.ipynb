# %%
# %matplotlib inline

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
gdp = pd.read_excel('income_per_person_gdppercapita_ppp_inflation_adjusted.xlsx')
idh = pd.read_excel('hdi_human_development_index.xlsx')
export = pd.read_excel('exports_percent_of_gdp.xlsx')

# %% [markdown]
# Selecionando os países que estão e que não estão no Mercosul para comparação

# %%
gdpnew = gdp.loc[:, ['country', 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007]]
gdpcompare = gdpnew.loc[(gdpnew.country=='Argentina') | (gdpnew.country=='Brazil') | (gdpnew.country=='Uruguay') | (gdpnew.country=='Paraguay') | (gdpnew.country=='Chile') | (gdpnew.country=='Peru') | (gdpnew.country=='Bolivia') | (gdpnew.country=='Colombia')]
gdpcompare
# Out:
#        country   1991   1992   1993   1994   1995   1996   1997   1998   1999  \
# 6    Argentina  12000  13300  13900  14500  13900  14500  15500  15900  15200
# 20     Bolivia   3830   3810   3900   4000   4110   4200   4320   4450   4390
# 23      Brazil  10300  10100  10400  10800  11100  11100  11300  11200  11100
# 34       Chile   9540  10400  11000  11300  12200  12800  13600  14000  13800
# 36    Colombia   7560   7800   7840   8160   8440   8480   8630   8550   8070
# 133   Paraguay   6090   6040   6190   6360   6640   6590   6720   6580   6360
# 134       Peru   5320   5190   5350   5900   6230   6300   6600   6480   6480
# 185    Uruguay  10100  10800  11000  11800  11500  12100  13000  13500  13200
#
#       2000   2001   2002   2003   2004   2005   2006   2007
# 6    14900  14100  12400  13400  14400  15500  16600  17900
# 20    4410   4400   4430   4470   4580   4700   4840   4970
# 23   11400  11400  11600  11500  12100  12300  12600  13300
# ...

# %%
idhnew = idh.loc[:, ['country', 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007]]
idhcompare = idhnew.loc[(idhnew.country=='Argentina') | (idhnew.country=='Brazil') | (idhnew.country=='Uruguay') | (idhnew.country=='Paraguay') | (idhnew.country=='Chile') | (idhnew.country=='Peru') | (idhnew.country=='Bolivia') | (idhnew.country=='Colombia')]
idhcompare
# Out:
#        country   1991   1992   1993   1994   1995   1996   1997   1998   1999  \
# 6    Argentina  0.713  0.720  0.725  0.728  0.731  0.738  0.746  0.753  0.764
# 20     Bolivia  0.543  0.549  0.556  0.564  0.571  0.577  0.579  0.591  0.600
# 23      Brazil  0.615  0.622  0.631  0.640  0.649  0.656  0.664  0.671  0.677
# 34       Chile  0.710  0.718  0.713  0.719  0.728  0.735  0.742  0.748  0.755
# 36    Colombia  0.595  0.606  0.613  0.620  0.626  0.635  0.643  0.650  0.650
# 130   Paraguay  0.585  0.589  0.596  0.600  0.606  0.613  0.618  0.622  0.625
# 131       Peru  0.616  0.616  0.621  0.632  0.642  0.647  0.654  0.664  0.674
# 179    Uruguay  0.697  0.700  0.703  0.709  0.711  0.717  0.727  0.735  0.738
#
#       2000   2001   2002   2003   2004   2005   2006   2007
# 6    0.771  0.776  0.770  0.775  0.780  0.782  0.788  0.792
# 20   0.607  0.610  0.617  0.620  0.622  0.625  0.626  0.632
# 23   0.685  0.692  0.699  0.695  0.694  0.698  0.700  0.704
# ...

# %%
exportnew = export.loc[:, ['country', 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007]]
exportcompare = exportnew.loc[(exportnew.country=='Argentina') | (exportnew.country=='Brazil') | (exportnew.country=='Uruguay') | (exportnew.country=='Paraguay') | (exportnew.country=='Chile') | (exportnew.country=='Peru') | (exportnew.country=='Bolivia') | (exportnew.country=='Colombia')]
exportcompare
# Out:
#        country   1991  1992   1993   1994   1995   1996   1997   1998   1999  \
# 5    Argentina   7.68   6.6   6.91   7.53   9.68  10.40  10.60  10.40   9.83
# 19     Bolivia  21.50  20.0  19.10  21.70  22.60  22.60  21.10  19.70  16.90
# 22      Brazil   8.68  10.9  10.50   9.67   7.53   6.73   6.98   7.03   9.56
# 33       Chile  31.30  29.0  25.90  27.50  28.60  26.60  26.50  25.50  28.80
# 35    Colombia  21.30  17.7  16.40  15.00  14.50  15.20  14.80  15.00  18.30
# 130   Paraguay  50.80  49.8  59.90  60.80  61.80  52.70  48.50  56.30  45.30
# 131       Peru  12.10  12.5  12.30  12.80  12.60  13.30  14.50  13.70  15.40
# 177    Uruguay  20.70  20.4  19.10  19.80  19.00  19.70  17.50  16.40  15.10
#
#      2000  2001  2002  2003  2004  2005  2006  2007
# 5    11.0  11.6  28.4  25.9  23.8  23.2  23.0  22.7
# 19   18.3  20.0  21.6  25.6  31.1  35.5  41.8  41.8
# 22   10.2  12.4  14.2  15.2  16.5  15.2  14.4  13.3
# 33   30.5  32.4  32.8  35.7  39.8  40.2  43.8  45.1
# ...

# %% [markdown]
# A fazer
#
# - Colocar uma variável para mostrar quais países são e quais países não são do Mercosul
# - Terminar as análises de IDH, PIB e Exportação
# - Gráficos

# %%
gdp = gdp.loc[:, ['country', 1991, 1996]]
gdp = gdp.rename(columns = {'country': 'País', 1991:'PIB1991', 1996: 'PIB1996'})

idh = idh.loc[:, ['country', 1991, 1996]]
idh = idh.rename(columns = {'country':'País', 1991:'IDH1991', 1996:'IDH1996'})

export = export.loc[:, ['country', 1991, 1996]]
export = export.rename(columns = {'country':'País', 1991:'EXPORT1991', 1996:'EXPORT1996'})

gdp_idx = gdp.set_index('País')
idh_idx = idh.set_index('País')
export_idx = export.set_index('País')

df = gdp_idx.join(idh_idx, how='inner')
data = df.join(export_idx, how='inner')

# %%
data = data.loc[['Argentina', 'Brazil', 'Uruguay', 'Paraguay', 'Chile', 'Peru', 'Colombia'], ['PIB1991', 'PIB1996', 'IDH1991', 'IDH1996', 'EXPORT1991', 'EXPORT1996']]
data['MERCOSUL'] = 'Sim'
data.loc[['Chile', 'Peru', 'Colombia'], ['MERCOSUL']] = 'Não'
data
# Out:
#            PIB1991  PIB1996  IDH1991  IDH1996  EXPORT1991  EXPORT1996 MERCOSUL
# País
# Argentina    12000    14500    0.713    0.738        7.68       10.40      Sim
# Brazil       10300    11100    0.615    0.656        8.68        6.73      Sim
# Uruguay      10100    12100    0.697    0.717       20.70       19.70      Sim
# Paraguay      6090     6590    0.585    0.613       50.80       52.70      Sim
# Chile         9540    12800    0.710    0.735       31.30       26.60      Não
# Peru          5320     6300    0.616    0.647       12.10       13.30      Não
# Colombia      7560     8480    0.595    0.635       21.30       15.20      Não

# %%
data.plot.scatter(x='PIB1996', y='IDH1996')

# %%
data.plot.scatter(x='PIB1996', y='EXPORT1996')

# %%
data.plot.scatter(x='EXPORT1996', y='IDH1996')

# %%
fig = plt.figure(figsize=(13, 4))

plt.subplot(131)
evc=data.PIB1991[data.MERCOSUL=='Sim']
evc.plot(kind='bar', title='PIB1991', legend=False)
plt.grid(True)

plt.subplot(132)
p1996 = data.PIB1996[data.MERCOSUL=='Sim']
p1996.plot(kind='bar', title='PIB1996', legend=False)
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(13, 4))

plt.subplot(131)
evc=data.IDH1991[data.MERCOSUL=='Sim']
evc.plot(kind='bar', title='IDH1991', legend=False)
plt.grid(True)

plt.subplot(132)
p1996 = data.IDH1996[data.MERCOSUL=='Sim']
p1996.plot(kind='bar', title='IDH1996', legend=False)
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
#médiapib em 1991 mercosul
mediapib = data.PIB1991[data.MERCOSUL=='Sim']
mediapib.mean()
mediapib.median()
# Out:
# 10200.0
